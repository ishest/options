# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Download BTC data
btc = yf.download("BTC-USD", start="2017-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
btc['Log_Return'] = np.log(btc['Adj Close'] / btc['Adj Close'].shift(1))

# %%
# Daily
btc['Daily_Vol'] = btc['Log_Return'].std()

# 3-days
btc['3_Days_Vol'] = btc['Log_Return'].rolling(window=3).std() * np.sqrt(365)

# 5-days
btc['5_Days_Vol'] = btc['Log_Return'].rolling(window=5).std() * np.sqrt(365)

# Weekly
btc['Weekly_Vol'] = btc['Log_Return'].rolling(window=7).std() * np.sqrt(365)

# Monthly (assuming 21 trading days in a month)
btc['Monthly_Vol'] = btc['Log_Return'].rolling(window=30).std()  * np.sqrt(365)

# Quarterly (assuming 63 trading days in a quarter)
btc['Quarterly_Vol'] = btc['Log_Return'].rolling(window=90).std() * np.sqrt(365)

# Bi-Quarter (assuming 126 trading days in a half-year)
btc['Bi_Quarter_Vol'] = btc['Log_Return'].rolling(window=182).std() * np.sqrt(365)

# Annualized (assuming 252 trading days in a year)
btc['Annualized_Vol'] = btc['Log_Return'].rolling(window=365).std() * np.sqrt(365)

# %%
btc.tail(1)[['Daily_Vol', '3_Days_Vol', '5_Days_Vol', 'Weekly_Vol', 'Monthly_Vol', 'Quarterly_Vol', 'Bi_Quarter_Vol', 'Annualized_Vol']]
# Out:
#             Daily_Vol  3_Days_Vol  5_Days_Vol  Weekly_Vol  Monthly_Vol  \
# Date
# 2023-08-17   0.039653    0.077093    0.148778    0.138492     0.182397
#
#             Quarterly_Vol  Bi_Quarter_Vol  Annualized_Vol
# Date
# 2023-08-17       0.346244        0.426602        0.494907

# %%
# Plotting
plt.figure(figsize=(14,7))
btc[['Daily_Vol', '3_Days_Vol', '5_Days_Vol', 'Weekly_Vol', 'Monthly_Vol', 'Quarterly_Vol', 'Bi_Quarter_Vol', 'Annualized_Vol']].plot(ax=plt.gca())
plt.title('BTC Volatility at Different Timeframes')
plt.ylabel('Volatility')
plt.xlabel('Date')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
volatility_columns = ['Daily_Vol', '3_Days_Vol', '5_Days_Vol', 'Weekly_Vol', 
                      'Monthly_Vol', 'Quarterly_Vol', 'Bi_Quarter_Vol', 'Annualized_Vol']

# %%
# for vol in volatility_columns:
plt.figure(figsize=(8,5))
btc['Daily_Vol'].plot(ax=plt.gca(), color='blue')
plt.title(f'BTC {vol.replace("_", " ")}')
plt.ylabel('Volatility')
plt.xlabel('Date')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
# for vol in volatility_columns:
plt.figure(figsize=(8,5))
btc['3_Days_Vol'].plot(ax=plt.gca(), color='blue')
plt.title(f'BTC {vol.replace("_", " ")}')
plt.ylabel('Volatility')
plt.xlabel('Date')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
btc['5_Days_Vol'].plot(ax=plt.gca(), color='blue')
plt.title(f'BTC {vol.replace("_", " ")}')
plt.ylabel('Volatility')
plt.xlabel('Date')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
btc['Weekly_Vol'].plot(ax=plt.gca(), color='blue')
plt.title(f'BTC {vol.replace("_", " ")}')
plt.ylabel('Volatility')
plt.xlabel('Date')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
btc['Monthly_Vol'].plot(ax=plt.gca(), color='blue')
plt.title(f'BTC {vol.replace("_", " ")}')
plt.ylabel('Volatility')
plt.xlabel('Date')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
btc['Quarterly_Vol'].plot(ax=plt.gca(), color='blue')
plt.title(f'BTC {vol.replace("_", " ")}')
plt.ylabel('Volatility')
plt.xlabel('Date')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
btc['Bi_Quarter_Vol'].plot(ax=plt.gca(), color='blue')
plt.title(f'BTC {vol.replace("_", " ")}')
plt.ylabel('Volatility')
plt.xlabel('Date')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
btc['Annualized_Vol'].plot(ax=plt.gca(), color='blue')
plt.title(f'BTC {vol.replace("_", " ")}')
plt.ylabel('Volatility')
plt.xlabel('Date')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()
